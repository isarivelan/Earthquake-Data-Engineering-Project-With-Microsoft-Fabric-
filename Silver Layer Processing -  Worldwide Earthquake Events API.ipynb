# %% [markdown]
# # Silver Layer Processing - Worldwide Earthquake Events API

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import TimestampType
# Out:
# StatementMeta(, 2e0c0eaf-b16d-4222-a250-b6a78374b58f, 4, Finished, Available, Finished)

# %%
# df now is a Spark DataFrame containing JSON data
df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake_data.json")
# Out:
# StatementMeta(, 2e0c0eaf-b16d-4222-a250-b6a78374b58f, 6, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, 2e0c0eaf-b16d-4222-a250-b6a78374b58f, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 58dfd593-2e5b-4c22-8960-2942f505fabc)

# %%
# Reshape earthquake data by extracting and renaming key attributes for further analysis.
df = \
df.\
    select(
        'id',
        col('geometry.coordinates').getItem(0).alias('longitude'),
        col('geometry.coordinates').getItem(1).alias('latitude'),
        col('geometry.coordinates').getItem(2).alias('elevation'),
        col('properties.title').alias('title'),
        col('properties.place').alias('place_description'),
        col('properties.sig').alias('sig'),
        col('properties.mag').alias('mag'),
        col('properties.magType').alias('magType'),
        col('properties.time').alias('time'),
        col('properties.updated').alias('updated')
        )
# Out:
# StatementMeta(, 2e0c0eaf-b16d-4222-a250-b6a78374b58f, 8, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, 2e0c0eaf-b16d-4222-a250-b6a78374b58f, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, be4e9490-4053-407e-8684-77701421c22a)

# %%
# Convert 'time' and 'updated' columns from milliseconds to timestamp format for clearer datetime representation.
df = df.\
    withColumn('time', col('time')/1000).\
    withColumn('updated', col('updated')/1000).\
    withColumn('time', col('time').cast(TimestampType())).\
    withColumn('updated', col('updated').cast(TimestampType()))
# Out:
# StatementMeta(, 2e0c0eaf-b16d-4222-a250-b6a78374b58f, 10, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, 2e0c0eaf-b16d-4222-a250-b6a78374b58f, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, b6b7da01-aa23-49f3-b87f-82407aa776a5)

# %%
# appending the data to the gold table
df.write.mode('append').saveAsTable('earthquake_events_silver')
# Out:
# StatementMeta(, 2e0c0eaf-b16d-4222-a250-b6a78374b58f, 12, Finished, Available, Finished)
